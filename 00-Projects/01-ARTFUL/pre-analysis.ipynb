# %%
import numpy as np

import xmitgcm as xm

import matplotlib.pyplot as plt
import holoviews as hv
hv.extension('bokeh')  # You can also use 'matplotlib' or 'plotly'

from scipy.interpolate import griddata
from datetime import timedelta, datetime

#%matplotlib notebook
# seaborn for interactive plots or bokee or hvplot
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="bec8df09-076f-4d4b-942a-d6813a2c97cb" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load ch1903 grid coordinates
x_ch1903 = np.load(r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\data\grid\50m\x_sg_grid.npy")
y_ch1903 = np.load(r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\data\grid\50m\y_sg_grid.npy")
x_mitgcm = np.load(r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\data\grid\50m\x.npy")
y_mitgcm = np.load(r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\data\grid\50m\y.npy")

# %%
mask = (slice(300, 500), slice(800, 1000))
# Setting the transformation from the mitgcm grid coordinates to ch1903
x_grid, y_grid = np.meshgrid(x_mitgcm,y_mitgcm)
coord_mitgcm_grid = np.array([x_grid[mask].flatten()/50, y_grid[mask].flatten()/50]).T
x_ch1903_flat = x_ch1903[mask].flatten()
y_ch1903_flat = y_ch1903[mask].flatten()

# %%
# Coordinates treatment plant
x_wwtp, y_wwtp = 534650,151350 
# Mitgcm index associated with those coordinates
index_grid_wwtp = (885.255248, 427.061058)
#index_grid_wwtp = griddata((x_ch1903_flat, y_ch1903_flat), coord_mitgcm_grid, (x_wwtp, y_wwtp), method='cubic')

# %%
ds = xm.open_mdsdataset(r"D:\geneva_forecast\results_bin_forecast_20240924", ref_date='2024-08-15 0:0:0', delta_t=4, endian='<')
# Out:
# C:\Users\leroquan\AppData\Local\anaconda3\envs\mitgcm_env\lib\site-packages\xmitgcm\mds_store.py:913: UserWarning: Couldn't find available_diagnostics.log in D:\geneva_forecast\results_bin_forecast_20240924 or D:\geneva_forecast\results_bin_forecast_20240924. Using default version.
#   warnings.warn("Couldn't find available_diagnostics.log "
# C:\Users\leroquan\AppData\Local\anaconda3\envs\mitgcm_env\lib\site-packages\xmitgcm\mds_store.py:913: UserWarning: Couldn't find available_diagnostics.log in D:\geneva_forecast\results_bin_forecast_20240924 or D:\geneva_forecast\results_bin_forecast_20240924. Using default version.
#   warnings.warn("Couldn't find available_diagnostics.log "
# C:\Users\leroquan\AppData\Local\anaconda3\envs\mitgcm_env\lib\site-packages\xmitgcm\mds_store.py:913: UserWarning: Couldn't find available_diagnostics.log in D:\geneva_forecast\results_bin_forecast_20240924 or D:\geneva_forecast\results_bin_forecast_20240924. Using default version.
# ...

# %%
ds_to_plot = ds.copy()

# %%
# Transform XC and YC into indexes
ds_to_plot['XC'] = range(len(ds_to_plot['XC']))
ds_to_plot['YC'] = range(len(ds_to_plot['YC']))

# %%
len(ds_to_plot['time'])
# Out:
# 7

# %%
ds_to_plot['time'].values
# Out:
# array(['2024-09-21T00:35:00.000000000', '2024-09-24T02:45:00.000000000',
#        '2024-09-24T08:05:00.000000000', '2024-09-24T13:55:00.000000000',
#        '2024-09-25T00:05:00.000000000', '2024-09-25T01:45:00.000000000',
#        '2024-09-25T13:15:00.000000000'], dtype='datetime64[ns]')

# %%
i_t = 2
T_plot = ds_to_plot['time'].values[i_t]
Z_plot = ds_to_plot['Z'].values[24]
print(T_plot)
print(Z_plot)
# Out:
# 2024-09-24T08:05:00.000000000
# -17.8975

# %%
subsetting_factor = 10
X_trimmed = ds_to_plot['XC'][::subsetting_factor]
Y_trimmed = ds_to_plot['YC'][::subsetting_factor]
U_trimmed = ds_to_plot['UVEL'].sel(time=T_plot, Z=Z_plot)[:,1:][::subsetting_factor,::subsetting_factor]
V_trimmed = ds_to_plot['VVEL'].sel(time=T_plot, Z=Z_plot)[1:,:][::subsetting_factor,::subsetting_factor]

# %%
xr_plot = ds_to_plot['THETA'].sel(time=T_plot, Z=Z_plot)
xr_plot = xr_plot.where(xr_plot != 0)
xr_plot.plot(cmap='jet', figsize=(15,5), vmax=20)
plt.axis('equal')
plt.quiver(X_trimmed, Y_trimmed, U_trimmed, V_trimmed, scale=10)
plt.scatter(index_grid_wwtp[0], index_grid_wwtp[1], color='red')
plt.title(f'time = {str(T_plot)[:19]}, Z = {round(Z_plot)}m')
# Out:
# Text(0.5, 1.0, 'time = 2024-09-24T08:05:00, Z = -18m')

# %%
# Convert to magnitude and angle
mag = np.sqrt(U_trimmed.values**2 + V_trimmed.values**2)
angle = (np.pi/2.) - np.arctan2(U_trimmed.values/mag, V_trimmed.values/mag)

vector_field = hv.VectorField((X_trimmed, Y_trimmed, angle, mag)).opts(
    color='black',  # Arrow color
    magnitude='Magnitude',  # Set arrow length to represent speed
    arrow_heads=True,  # Display arrow heads
    scale=0.5,  # Scale of arrows
    width=600, height=400,
    title='Water Velocity Field'
)
# Out:
# C:\Users\leroquan\AppData\Local\Temp\ipykernel_9136\794750170.py:3: RuntimeWarning: invalid value encountered in divide
#   angle = (np.pi/2.) - np.arctan2(U_trimmed.values/mag, V_trimmed.values/mag)

# %%
image_index = hv.Image(xr_plot, kdims=[xr_plot.dims[1], xr_plot.dims[0]])
image_index = image_index.opts(tools=['hover'], colorbar=True, cmap='viridis', width=1600, height=800, title= f'time = {str(T_plot)[:19]}, Z = {round(Z_plot)}m')

# %%
image_index
# Out:
# :Image   [XC,YC]   (Potential Temperature)

# %% [markdown]
# ### Add wwtp outlet point to the display

# %%
wwtp_point = hv.Points([index_grid_wwtp])
wwtp_point = wwtp_point.opts( color='red', marker='o', size=5)

# %% [markdown]
# ### Display measurement points

# %% [markdown]
# meas_coordinates = [(534650,151350),
#                     (534670,151370)]
# # Transform ch1903 into mitgcm index
# meas_indexes = []
# for coor in meas_coordinates:
#     index_x, index_y = griddata((x_ch1903_flat, y_ch1903_flat), coord_mitgcm_grid, coor, method='cubic')
#     meas_indexes.append((index_x, index_y))
# # Add points on the display
# meas_points = hv.Points((np.array(meas_indexes)[:,0], np.array(meas_indexes)[:,1]))
# meas_points = meas_points.opts( color='black', marker='x', size=5)

# %% [markdown]
# ### Transform index to ch1903 coordinates

# %%
index_x0 = 885
index_y0 = 427
x0_ch1903, y0_ch1903 = griddata(coord_mitgcm_grid, np.array([x_ch1903_flat, y_ch1903_flat]).T, (index_x0, index_y0), method='cubic')
print('x: ', x0_ch1903)
print('y: ', y0_ch1903)
# Out:
# x:  534638.9777221318
# y:  151342.87907687394

# %% [markdown]
# ### Display everything

# %%
image_index * vector_field * wwtp_point
# Out:
# :Overlay
#    .Image.I       :Image   [XC,YC]   (Potential Temperature)
#    .VectorField.I :VectorField   [x,y]   (Angle,Magnitude)
#    .Points.I      :Points   [x,y]

# %% [markdown]
# ### Display lake slice

# %%
ds_to_plot['THETA'].sel(XC=885,time=T_plot, method='nearest').plot()
plt.gca()
# Out:
# <Axes: title={'center': 'iter = 897525, time = 2024-09-25T13:15:00, XC =...'}, xlabel='YC', ylabel='vertical coordinate of cell\ncenter [m]'>

# %% [markdown]
# ### Plot profile WWTP outlet

# %%
profile_temp = ds_to_plot['THETA'].sel(XC = index_grid_wwtp[0], YC = index_grid_wwtp[1], time = T_plot, method='nearest').values

# %%
from matplotlib.ticker import MultipleLocator

# %%
plt.plot(profile_temp[profile_temp>0], ds_to_plot['Z'][profile_temp>0])
plt.grid()

ax=plt.gca()
ax.yaxis.set_major_locator(MultipleLocator(2))
ax.xaxis.set_major_locator(MultipleLocator(0.5))
plt.xlabel(r'Temperature (°C)')
plt.ylabel(r'Depth (m)')
plt.title(r'Temperature profile WWTP outlet - ' + str(T_plot))
# Out:
# Text(0.5, 1.0, 'Temperature profile WWTP outlet - 2024-09-25T13:15:00.000000000')

# %%
timeserie_temp = ds_to_plot['THETA'].sel(XC = round(index_grid_wwtp[0],0), YC = round(index_grid_wwtp[1],0), Z=Z_plot).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 timeserie_temp = ds_to_plot['THETA'].sel(XC = round(index_grid_wwtp[0],0), YC = round(index_grid_wwtp[1],0), Z=Z_plot).plot()
#
# File ~\AppData\Local\anaconda3\envs\mitgcm_env\lib\site-packages\xarray\plot\accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\mitgcm_env\lib\site-packages\xarray\plot\dataarray_plot.py:282, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     279 plotfunc: Callable
#     281 if ndims == 0 or darray.size == 0:
# --> 282     raise TypeError("No numeric data to plot.")
#     283 if ndims in (1, 2):
# ...

# %%
i_t += -1
T_plot = ds_to_plot['time'].values[i_t]
Z_plot = ds_to_plot['Z'].values[0]
print(T_plot)
ds_to_plot['THETA'].sel(Z=Z_plot,time=T_plot)[300:450,800:950].plot(figsize=(15,8), vmin=17, vmax=26)
plt.scatter(885.255248, 427.061058)

# %%
ds_weather = xm.open_mdsdataset(r"D:\geneva_init\weather", ref_date='2024-08-15 0:0:0', delta_t=4, endian='<')

# %%
ds_weather['surForcT'].sel(time=ds_weather['surForcT']['time'][-1].values).plot(figsize=(15,8))

# %%
ds_weather['surForcT'].sel(XC = 44275, YC = 21375).plot()

# %%
ds_weather['surForcT']['time'][-1].values

# %%
ds_weather['XC'].values

# %%
427.061058 *50
