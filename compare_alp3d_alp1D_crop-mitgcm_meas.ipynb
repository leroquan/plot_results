# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from datetime import datetime
import os
import json
import numpy as np
import pandas as pd
import xarray as xr

# %%
from alplakes import parse_alplakes_3d_timeserie_from_directory, get_3d_profile_from_api, parse_json_3d_profile_to_df, parse_alplakes_1d_from_directory
from utils import save_json, open_json

# %% [markdown]
# ### Parameters

# %%
lake_name = "lucerne"
year = 2025
model = f'{year}'
save_figures = True

# %%
var_to_plot = 'THETA'

# %%
mitgcm_paths = [r"E:\05-Finale runs\lucerne_100m\crop_results\sta_depth_time.nc"] #start and end date are defined based on the 1st dataset
mitgcm_labels = ["MITgcm"]
mitgcm_color = ['b', 'violet', 'purple', 'darkblue']

# %%
alplakes3d_sta_names = [] #"geneva_lexplore"
alplakes3d_labels = ['Delft3D 3D (from Alplakes)']
alplakes3d_color = ['orange']

# %%
measure_ds_paths = [f'./data/measures/lucerne/walter/{year}.nc'] #rmse is computed based on the 1st dataset
measure_labels = [f'Walter Measure']
measure_color = ['r']

# %%
alplakes1d_folder_paths = ["./data/alplakes_1d/lucernekreuztrichterandvitznauerbecken"] #['./data/alplakes_1d/lucernekreuztrichterandvitznauerbecken/']
alplakes1d_labels = ['Simstrat 1D (from Alplakes)']
alplakes1d_colors = ['g']

# %% [markdown]
# ## Import cropped netcdf MITgcm results

# %%
xr_mitgcm = []
for i in range(len(mitgcm_paths)):
    xr_mitgcm.append(xr.open_dataset(mitgcm_paths[i]))

# %% [markdown]
# xr_merged = xr.concat([xr_mitgcm[0], xr_mitgcm[1]], dim='time')

# %% [markdown]
# xr_merged = xr_merged.sel(time=~xr_merged.get_index("time").duplicated())
# xr_merged.to_netcdf(r'E:\05-Finale runs\geneva_100m\sta_depth_time_m.nc')

# %%
xr_mitgcm[0]['THETA'].isel(Z=1).plot()
plt.show()

# %% [markdown]
# ## Import measure

# %%
start_date = pd.to_datetime(xr_mitgcm[0]['time'].values[0]).to_pydatetime()  #datetime(2024, 1, 1, 0, 0, 0)
end_date = pd.to_datetime(xr_mitgcm[0]['time'].values[-1]).to_pydatetime() #datetime(2025, 1, 1, 0, 0, 0)

# %%
xr_measures = []
for i in range(len(measure_ds_paths)):
    xr_measures.append(xr.open_dataset(measure_ds_paths[i]))

# %%
xr_measures[0].temp.plot()
plt.show()

# %% [markdown]
# ## Import 1D simstrat alplakes

# %%
# Folder containing the JSON files
simstrat_data = []
for i in range(len(alplakes1d_folder_paths)):
    simstrat_data.append(parse_alplakes_1d_from_directory(alplakes1d_folder_paths[i]))

# %% [markdown]
# ## Alplakes 3D

# %%
def load_alplakes_3d(station_name: str, depth: int):
    alplakes_directory = rf".\data\alplakes_3d\{station_name}\timeseries_{-depth}m"
    
    if os.path.exists(alplakes_directory):   
        df_alplakes = parse_alplakes_3d_timeserie_from_directory(alplakes_directory)
        
        xr_alplakes = xr.Dataset(
            {
                'temperature': (['time'], df_alplakes['temperature'])
            },
            coords={
                'time': df_alplakes['time']
            }
        )
        
        unique_values, unique_ind = np.unique(xr_alplakes['time'].values, return_index=True)
        
        return xr_alplakes.isel(time=np.sort(unique_ind))
    else:
        return None

# %% [markdown]
# ## Resample timeseries

# %%
def interpolate_to_time_axis(xr_ds, time_axis, max_gap):
    interp_result = xr_ds.interp(time=time_axis)
    nearest_times = xr_ds.time.sel(time=time_axis, method="nearest")
    time_diff = abs(nearest_times - time_axis)
    interp_result = interp_result.where(time_diff.values <= max_gap, np.nan)
    
    return interp_result

# %%
def resample_all_timeseries(time_step, depth_plot, max_gap_allowed):    
    common_time_axis = pd.date_range(
        start=pd.Timestamp(xr_mitgcm[0].time.min().values).normalize(), 
        end=pd.Timestamp(xr_mitgcm[0].time.max().values), 
        freq=time_step
    )

    meas_interp = []
    for i in range(len(xr_measures)):
        meas_selected = xr_measures[i]['temp'].sel(depth=depth_plot, method='nearest')
        meas_interp.append(interpolate_to_time_axis(meas_selected, common_time_axis, max_gap_allowed))
    
    simstrat_interp = []
    for i in range(len(simstrat_data)):
        simstrat_selected = simstrat_data[i]['temperature'].sel(depth=-depth_plot, method='nearest')
        simstrat_interp.append(interpolate_to_time_axis(simstrat_selected, common_time_axis, max_gap_allowed))

    alplakes_interp = []
    for i in range(len(alplakes3d_sta_names)):
        alplakes_selected = load_alplakes_3d(alplakes3d_sta_names[i], depth_plot)['temperature']
        alplakes_interp.append(interpolate_to_time_axis(alplakes_selected, common_time_axis, max_gap_allowed))
    
    mitgcm_interp = []
    for i in range(len(xr_mitgcm)):
        mitgcm_selected=xr_mitgcm[i]['THETA'].sel(Z=depth_plot, method='nearest')
        mitgcm_interp_time = interpolate_to_time_axis(mitgcm_selected, common_time_axis, max_gap_allowed)
        mitgcm_interp.append(mitgcm_interp_time)
    
    return meas_interp, simstrat_interp, alplakes_interp, mitgcm_interp

# %% [markdown]
# ## Compute RMSE

# %%
def compute_rmse(prediction, measures):
    return np.sqrt(np.nanmean((prediction - measures) ** 2))

# %%
def compute_rmse_all_timeseries(meas_interp, mitgcm_interp, simstrat_interp, alplakes_interp):
    rmse_simstrat = []
    for i in range(len(simstrat_interp)):
        rmse_simstrat.append(compute_rmse(simstrat_interp[i].values, meas_interp[0].values))

    rmse_alplakes = []
    for i in range(len(alplakes_interp)):
        rmse_alplakes.append(compute_rmse(alplakes_interp[i].values, meas_interp[0].values))
    
    rmse_mitgcm = []
    for i in range(len(mitgcm_interp)):
        rmse_mitgcm.append(compute_rmse(mitgcm_interp[i].values, meas_interp[0].values))
        
    return rmse_mitgcm, rmse_simstrat, rmse_alplakes

# %% [markdown]
# ## Plot timeserie

# %%
time_step = '1h'
depth_plot=-1 # Value should be negative !!
max_gap_allowed = np.timedelta64(3, 'h') 

meas_interp, simstrat_interp, alplakes_interp, mitgcm_interp = resample_all_timeseries(time_step, depth_plot, max_gap_allowed)
rmse_mitgcm, rmse_simstrat, rmse_alplakes = compute_rmse_all_timeseries(meas_interp, mitgcm_interp, simstrat_interp, alplakes_interp)

# %%
# %matplotlib inline
plt.close('all')
fig, ax = plt.subplots(1,1,figsize=(15, 7))

for i in range(len(mitgcm_interp)):
    mitgcm_interp[i].plot(label=f'{mitgcm_labels[i]}, RMSE={rmse_mitgcm[i]:.2f}', color=mitgcm_color[i])

for i in range(len(simstrat_interp)):
    simstrat_interp[i].plot(label=f'{alplakes1d_labels[i]}, RMSE={rmse_simstrat[i]:.2f}', color=alplakes1d_colors[i])

for i in range(len(alplakes_interp)):
    alplakes_interp[i].plot(label=f'{alplakes3d_labels[i]}, RMSE={rmse_alplakes[i]:.2f}', color=alplakes3d_color[i])

for i in range(len(meas_interp)):
    meas_interp[i].plot(label=measure_labels[i], color=measure_color[i], lw=1)

plt.grid(True, which='both', linestyle='-', linewidth=0.5)
plt.legend()
ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
plt.ylabel('Temperature (°C)')
plt.title(f"Temperature at depth {depth_plot}m")

plot_path = rf"output_plots\{lake_name}\{model}_{depth_plot}m.png"
if save_figures:
    plt.savefig(plot_path)
    print(f'Saved plot to {plot_path}')
plt.show()
# Out:
# Saved plot to output_plots\lucerne\2025_-1m.png

# %%
# %matplotlib inline
# Flush old figures
plt.close('all')

# Define depths
depths = [-1, -10, -20]

# Create figure with 3 subplots
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)
# Loop through subplots and depths
for i, depth_plot in enumerate(depths):
    ax = axes[i]
    
    meas_interp, simstrat_interp, alplakes_interp, mitgcm_interp = resample_all_timeseries(time_step, depth_plot, max_gap_allowed)
    rmse_mitgcm, rmse_simstrat, rmse_alplakes = compute_rmse_all_timeseries(meas_interp, mitgcm_interp, simstrat_interp, alplakes_interp)

    # Plot data
    for j in range(len(mitgcm_interp)):
        mitgcm_interp[j].resample(time='d').mean().plot(ax=ax, label=f'{mitgcm_labels[j]}, RMSE={rmse_mitgcm[j]:.2f}', lw=1, color=mitgcm_color[j])

    for j in range(len(simstrat_interp)):
        simstrat_interp[j].resample(time='d').mean().plot(ax=ax, label=f'{alplakes1d_labels[j]}, RMSE={rmse_simstrat[j]:.2f}', color=alplakes1d_colors[j], lw=1)

    for j in range(len(alplakes_interp)):
        alplakes_interp[j].resample(time='d').mean().plot(ax=ax, label=f'{alplakes3d_labels[j]}, RMSE={rmse_alplakes[j]:.2f}', color=alplakes3d_color[j], lw=1)

    for j in range(len(meas_interp)):
        meas_interp[j].resample(time='d').mean().plot(ax=ax, label=measure_labels[j], color=measure_color[j], lw=1)

    # Grid, axis formatting
    ax.grid(True, which='both', linestyle='-', linewidth=0.5)
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.set_xlabel(None)
    ax.set_ylabel('Temperature (°C)')
    ax.set_title(None)  # Completely remove the title

    # Add depth as a subtitle inside the plot
    ax.text(
        0.98, 0.9, f'Depth: {depth_plot}m', 
        transform=ax.transAxes, fontsize=12,
        verticalalignment='top', horizontalalignment='right',  # Align text to the right
        bbox=dict(facecolor='white', alpha=0.6, edgecolor='black')
    )
    ax.legend() 

# Global title
fig.suptitle("Temperature at LéXPLORE (Lake Geneva)", fontsize=14)

plt.xlabel("Time")  # Add x-axis label
plt.tight_layout()  # Adjust layout

plot_path = rf"output_plots\{lake_name}\{model}_multidepths.png"
if save_figures:
    plt.savefig(plot_path)
    print(f'Saved plot to {plot_path}')

plt.show()
# Out:
# Saved plot to output_plots\lucerne\2025_multidepths.png

# %% [markdown]
# # Profile

# %%
def get_alplakes_profile(date_plot_profil_str, sta_name):
    with open(os.path.join('./config_points.json'), 'r') as file:
        config_points = json.load(file)[sta_name]
    
    lat_station_wgs84 = config_points['lat_station_wgs84']
    long_station_wgs84 = config_points['long_station_wgs84']
    
    alplakes_profile_json_path = rf".\data\alplakes_3d\{sta_name}\profiles\profile_{sta_name}_{date_plot_profil_str}m.json"
    if not os.path.isfile(alplakes_profile_json_path):
        alplakes_profile_json = get_3d_profile_from_api(lake_name, date_plot_profil_str, lat_station_wgs84, long_station_wgs84)
        save_json(alplakes_profile_json, alplakes_profile_json_path)
    else:
        alplakes_profile_json = open_json(alplakes_profile_json_path)
    
    return parse_json_3d_profile_to_df(alplakes_profile_json)

# %%
date_plot_profil = datetime(year,10, 1, 12,0,0)
date_plot_profil_str = date_plot_profil.strftime('%Y%m%d%H%M')

# %%
from datetime import timedelta

# %%
# %matplotlib inline
while date_plot_profil < datetime(2026,1,1,12,0,0):
    plt.close('all')
    fig, ax = plt.subplots(1,1,figsize=(5, 7))

    for i in range(len(xr_measures)):
        meas_profile = xr_measures[i]['temp'].sel(time=date_plot_profil, method='nearest')
        plt.plot(meas_profile.values, meas_profile.depth.values, label=measure_labels[i], color=measure_color[i])

    for i in range(len(xr_mitgcm)):
        profile_mitgcm = xr_mitgcm[i][var_to_plot].sel(time=date_plot_profil, method='nearest')
        profile_mitgcm.where(profile_mitgcm != 0, np.nan).plot(y='Z', label=f'{mitgcm_labels[i]}', color=mitgcm_color[i])

    for i in range(len(alplakes3d_sta_names)):
        alplakes_profile = get_alplakes_profile(date_plot_profil_str, alplakes3d_sta_names[i])
        plt.plot(alplakes_profile['temperature'],-1*alplakes_profile['depth'], label=alplakes3d_labels[i], color=alplakes3d_color[i])

    for i in range(len(simstrat_data)):
    # Convert Simstrat depth to negative and plot
        simstrat_depth_negative = -simstrat_data[i]['depth'].values  # Convert to negative NumPy array
        simstrat_temperature = simstrat_data[i]['temperature'].sel(time=date_plot_profil, method='nearest')
        plt.plot(simstrat_temperature.values, simstrat_depth_negative, label=alplakes1d_labels[i], color=alplakes1d_colors[i])

    plt.title(f"{date_plot_profil}")
    plt.grid(True, which='both', linestyle='-', linewidth=0.5)
    plt.ylabel('Depth (m)')
    plt.ylim(bottom=-100, top=1)
    plt.xlim(left=5, right=26)
    plt.xlabel('Temperature (°C)')
    ax.xaxis.set_major_locator(ticker.MultipleLocator(2))
    plt.legend()
    if save_figures:
        plt.savefig(rf"output_plots\{lake_name}\{model}_profile_{date_plot_profil.strftime('%Y%m%d_%H%M')}.png")

    plt.close('all')


    date_plot_profil += timedelta(days=1)
    date_plot_profil_str = date_plot_profil.strftime('%Y%m%d%H%M')

# %%
profile_mitgcm = xr_mitgcm[0][var_to_plot].sel(time=date_plot_profil, method='nearest')
profile_mitgcm.where(profile_mitgcm != 0, np.nan).plot(y='Z', label=f'{mitgcm_labels[0]}', color=mitgcm_color[0])
plt.gca().set_ylim(bottom=-20)
plt.show()
date_plot_profil += timedelta(hours=12)
