# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
bin_file_path = r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\2024_08_19_run_fazel_cscs\binary_data\bathyGeneva_50m.bin"

# %%
with open(bin_file_path, 'rb') as fid:
    binary_data = np.fromfile(fid, dtype='<f8')

# %%
binary_data
# Out:
# array([2., 2., 2., ..., 2., 2., 2.])

# %%
plt.plot(binary_data)

# %%
bin_file_path = r"C:\Users\leroquan\Documents\00-Work_space\06-mit_gcm_geneva\2024_07_31_geneva_100m\binary_data\bathyGeneva_100m.bin"

# %%
with open(bin_file_path, 'rb') as fid:
    binary_data = np.fromfile(fid, dtype='>f8')

# %%
binary_data
# Out:
# array([2., 2., 2., ..., 2., 2., 2.], dtype='>f8')

# %%
plt.plot(binary_data)
